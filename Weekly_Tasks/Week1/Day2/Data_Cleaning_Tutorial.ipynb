# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading the dataset

# %%
df=pd.read_csv('Titanic-Dataset.csv')

# %% [markdown]
# # Handling Null Values

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Check for null values (1 line)
df.isnull().sum()
# Fill null values for 'Embarked' with the mode(1 line)
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
# Drop rows with null values in 'Cabin' (or alternatively, you can fill it with a placeholder) (1 line)
df.dropna(subset = ['Cabin'], inplace = True)
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            19
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        0
# dtype: int64

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
# Out:
# C:\Users\lordm\AppData\Local\Temp\ipykernel_5484\2531022806.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
df.dropna(subset = ['Cabin'], inplace = True)

# %%
df["Cabin"].fillna("Unknown", inplace = True)
# Out:
# C:\Users\lordm\AppData\Local\Temp\ipykernel_5484\77794017.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Cabin"].fillna("Unknown", inplace = True)

# %%
df.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
# 30           31         0       1
# 31           32         1       1
# 32           33         1       3
# 33           34         0       2
# 34           35         0       1
# 35           36         0       1
# 36           37         1       3
# 37           38         0       3
# 38           39         0       3
# 39           40         1       3
# 40           41         0       3
# 41           42         0       2
# 42           43         0       3
# 43           44         1       2
# 44           45         1       3
# 45           46         0       3
# 46           47         0       3
# 47           48         1       3
# 48           49         0       3
# 49           50         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                            Emir, Mr. Farred Chehab    male   NaN      0
# 27                     Fortune, Mr. Charles Alexander    male  19.0      3
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                Todoroff, Mr. Lalio    male   NaN      0
# 30                           Uruchurtu, Don. Manuel E    male  40.0      0
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 32                           Glynn, Miss. Mary Agatha  female   NaN      0
# 33                              Wheadon, Mr. Edward H    male  66.0      0
# 34                            Meyer, Mr. Edgar Joseph    male  28.0      1
# 35                     Holverson, Mr. Alexander Oskar    male  42.0      1
# 36                                   Mamee, Mr. Hanna    male   NaN      0
# 37                           Cann, Mr. Ernest Charles    male  21.0      0
# 38                 Vander Planke, Miss. Augusta Maria  female  18.0      2
# 39                        Nicola-Yarred, Miss. Jamila  female  14.0      1
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 41  Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 42                                Kraeff, Mr. Theodor    male   NaN      0
# 43           Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 44                      Devaney, Miss. Margaret Delia  female  19.0      0
# 45                           Rogers, Mr. William John    male   NaN      0
# 46                                  Lennon, Mr. Denis    male   NaN      1
# 47                          O'Driscoll, Miss. Bridget  female   NaN      0
# 48                                Samaan, Mr. Youssef    male   NaN      2
# 49      Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
#
#     Parch            Ticket      Fare        Cabin Embarked
# 0       0         A/5 21171    7.2500      Unknown        S
# 1       0          PC 17599   71.2833          C85        C
# 2       0  STON/O2. 3101282    7.9250      Unknown        S
# 3       0            113803   53.1000         C123        S
# 4       0            373450    8.0500      Unknown        S
# 5       0            330877    8.4583      Unknown        Q
# 6       0             17463   51.8625          E46        S
# 7       1            349909   21.0750      Unknown        S
# 8       2            347742   11.1333      Unknown        S
# 9       0            237736   30.0708      Unknown        C
# 10      1           PP 9549   16.7000           G6        S
# 11      0            113783   26.5500         C103        S
# 12      0         A/5. 2151    8.0500      Unknown        S
# 13      5            347082   31.2750      Unknown        S
# 14      0            350406    7.8542      Unknown        S
# 15      0            248706   16.0000      Unknown        S
# 16      1            382652   29.1250      Unknown        Q
# 17      0            244373   13.0000      Unknown        S
# 18      0            345763   18.0000      Unknown        S
# 19      0              2649    7.2250      Unknown        C
# 20      0            239865   26.0000      Unknown        S
# 21      0            248698   13.0000          D56        S
# 22      0            330923    8.0292      Unknown        Q
# 23      0            113788   35.5000           A6        S
# 24      1            349909   21.0750      Unknown        S
# 25      5            347077   31.3875      Unknown        S
# 26      0              2631    7.2250      Unknown        C
# 27      2             19950  263.0000  C23 C25 C27        S
# 28      0            330959    7.8792      Unknown        Q
# 29      0            349216    7.8958      Unknown        S
# 30      0          PC 17601   27.7208      Unknown        C
# 31      0          PC 17569  146.5208          B78        C
# 32      0            335677    7.7500      Unknown        Q
# 33      0        C.A. 24579   10.5000      Unknown        S
# 34      0          PC 17604   82.1708      Unknown        C
# 35      0            113789   52.0000      Unknown        S
# 36      0              2677    7.2292      Unknown        C
# 37      0        A./5. 2152    8.0500      Unknown        S
# 38      0            345764   18.0000      Unknown        S
# 39      0              2651   11.2417      Unknown        C
# 40      0              7546    9.4750      Unknown        S
# 41      0             11668   21.0000      Unknown        S
# 42      0            349253    7.8958      Unknown        C
# 43      2     SC/Paris 2123   41.5792      Unknown        C
# 44      0            330958    7.8792      Unknown        Q
# 45      0   S.C./A.4. 23567    8.0500      Unknown        S
# 46      0            370371   15.5000      Unknown        Q
# 47      0             14311    7.7500      Unknown        Q
# 48      0              2662   21.6792      Unknown        C
# 49      0            349237   17.8000      Unknown        S

# %% [markdown]
# # Handling Duplicates

# %%
# Check for duplicates (1 line)
df.duplicated().sum()

# Drop duplicates if any (1 line)
df= df.drop_duplicates()

# %% [markdown]
# # Handling Outliers

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(df['Fare'])
plt.show()

# %%
import numpy as np

# Function to remove outliers using the IQR method
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Remove outliers from 'Fare' using the remove_outilers function (1 line)
df = remove_outliers(df , 'Fare')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x=df['Fare'])
plt.show()

# %% [markdown]
# # Scaling and Normalization

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Standard scaling for 'Fare' (2 lines)


# Min-Max scaling for 'Age' (2 lines)

# %%
scaler = StandardScaler()
S_df = pd.DataFrame(scaler.fit_transform(df[["Fare"]]))
# or df["fare_aftre"] = scaler.fit_transform(df[["Fare"]])
print("before")
print(df["Fare"])
print("\n after")
print(S_df)
# Out:
# before
# 3      53.1000
# 6      51.8625
# 10     16.7000
# 11     26.5500
# 21     13.0000
#         ...
# 867    50.4958
# 871    52.5542
# 872     5.0000
# 887    30.0000
# 889    30.0000
# Name: Fare, Length: 114, dtype: float64
#
#  after
#             0
# 0    1.220665
# 1    1.146489
# 2   -0.961153
# 3   -0.370743
# 4   -1.182931
# ..        ...
# 109  1.064569
# 110  1.187950
# 111 -1.662452
# 112 -0.163950
# 113 -0.163950
#
# [114 rows x 1 columns]

# %%
scaler2 = MinMaxScaler()
MM_df = pd.DataFrame(scaler2.fit_transform(df[["Age"]]))
#or  df["age_aftre"] = scaler2.fit_transform(df[["age"]])
print("before")
print(df["Age"])
print("\n after")
print(MM_df)
# Out:
# before
# 3      35.0
# 6      54.0
# 10      4.0
# 11     58.0
# 21     34.0
#        ...
# 867    31.0
# 871    47.0
# 872    33.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 114, dtype: float64
#
#  after
#             0
# 0    0.430380
# 1    0.670886
# 2    0.037975
# 3    0.721519
# 4    0.417722
# ..        ...
# 109  0.379747
# 110  0.582278
# 111  0.405063
# 112  0.227848
# 113  0.316456
#
# [114 rows x 1 columns]

# %% [markdown]
# # Encoding Categorical Variables

# %%
# One-hot encoding for 'Embarked' and 'Sex' (1 line)
OHE_df = pd.get_dummies(df , columns = ['Embarked' , 'Sex'])
OHE_df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
# 21           22         1       2
#
#                                             Name   Age  SibSp  Parch   Ticket  \
# 3   Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0   113803
# 6                        McCarthy, Mr. Timothy J  54.0      0      0    17463
# 10               Sandstrom, Miss. Marguerite Rut   4.0      1      1  PP 9549
# 11                      Bonnell, Miss. Elizabeth  58.0      0      0   113783
# 21                         Beesley, Mr. Lawrence  34.0      0      0   248698
#
#        Fare Cabin  Embarked_C  Embarked_Q  Embarked_S  Sex_female  Sex_male
# 3   53.1000  C123       False       False        True        True     False
# 6   51.8625   E46       False       False        True       False      True
# 10  16.7000    G6       False       False        True        True     False
# 11  26.5500  C103       False       False        True        True     False
# 21  13.0000   D56       False       False        True       False      True

# %%
from sklearn.preprocessing import LabelEncoder 
label_encoder = LabelEncoder()
df["Embarked_labled"] = label_encoder.fit_transform(df["Embarked"])
df.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
# 21           22         1       2
# 23           24         1       1
# 54           55         0       1
# 55           56         1       1
# 66           67         1       2
# 75           76         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 3   Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 6                        McCarthy, Mr. Timothy J    male  54.0      0      0
# 10               Sandstrom, Miss. Marguerite Rut  female   4.0      1      1
# 11                      Bonnell, Miss. Elizabeth  female  58.0      0      0
# 21                         Beesley, Mr. Lawrence    male  34.0      0      0
# 23                  Sloper, Mr. William Thompson    male  28.0      0      0
# 54                Ostby, Mr. Engelhart Cornelius    male  65.0      0      1
# 55                             Woolner, Mr. Hugh    male   NaN      0      0
# 66                  Nye, Mrs. (Elizabeth Ramell)  female  29.0      0      0
# 75                       Moen, Mr. Sigurd Hansen    male  25.0      0      0
#
#         Ticket     Fare  Cabin Embarked  Embarked_labled
# 3       113803  53.1000   C123        S                2
# 6        17463  51.8625    E46        S                2
# 10     PP 9549  16.7000     G6        S                2
# 11      113783  26.5500   C103        S                2
# 21      248698  13.0000    D56        S                2
# 23      113788  35.5000     A6        S                2
# 54      113509  61.9792    B30        C                0
# 55       19947  35.5000    C52        S                2
# 66  C.A. 29395  10.5000    F33        S                2
# 75      348123   7.6500  F G73        S                2

# %%
mapping = {"S" : 1,"C" : 2,"Q" : 3,}

# %%
df["Embarked"] = df["Embarked"].map(mapping)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin  Embarked
# 0      0         A/5 21171   7.2500   NaN       1.0
# 1      0          PC 17599  71.2833   C85       2.0
# 2      0  STON/O2. 3101282   7.9250   NaN       1.0
# 3      0            113803  53.1000  C123       1.0
# 4      0            373450   8.0500   NaN       1.0
